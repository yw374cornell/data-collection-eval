# %%
import sys

# %%
sys.path.insert(0, "../../src/")

# %%
import analysis.common as ac
import analysis.accuracy_eval as aa

# %%
reload(aa)
# Out:
# <module 'analysis.accuracy_eval' from '../../src/analysis/accuracy_eval.pyc'>

# %%
(iphone_ids, android_ids, phone_labels) = ac.setupPaths()

# %%
import emission.core.get_database as edb
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as pydt
import emission.storage.timeseries.abstract_timeseries as esta

# %%
display_names = [ac.get_display_name(label) for label in phone_labels]

# %%
iphone_ts_list = [esta.TimeSeries.get_time_series(id) for id in iphone_ids]
android_ts_list = [esta.TimeSeries.get_time_series(id) for id in android_ids]

# %% [markdown]
# # Determine transitions

# %% [markdown]
# So trips are:
# - School to train stn:
#  - 2015-12-01T08:18:30.533000-08:00, 1448986710 (no ground truth)
#  - 2015-12-01T08:49:35.140000-08:00, 1448988575
# - Train station to home to train station:
#  - 2015-12-01T09:04:27-08:00, 1448989467
#  - 2015-12-01T09:40:21-08:00, 1448991621
# - Train station to Soda:
#  - 2015-12-01T10:11:18-08:00, 1448993478
#  - 2015-12-01T12:20:57.788000-08:00 1449001257.79 (no ground truth)
# - Soda to home:
#  - 2015-12-01T17:57:53-08:00, 1449021473
#  - 2015-12-01T20:56:47.250000-08:00, 1449032207.25 (no ground truth)

# %%
# And in code:
trips_list = [["school_to_train", 1448986710, 1448988575],
              ["train_home_train", 1448989467, 1448991621],
              ["train_to_soda", 1448993478, 1449001257.79],
              ["soda_to_home", 1449021473, 1449032207.25]
]

# %%
ground_truth_df = pd.read_csv("../../ground_truth/trip_to_berkeley.tuesday.2015-12-01/states.summary")
moving_df = ground_truth_df[ground_truth_df.state == "moving"]
moving_df
# Out:
#      start_ts             start_fmt_time      end_ts  \
# 0  1448986710  2015-12-01T08:18:30-08:00  1448988575
# 2  1448989467  2015-12-01T09:04:27-08:00  1448991621
# 4  1448993478  2015-12-01T10:11:18-08:00  1449001257
# 6  1449021473  2015-12-01T17:57:53-08:00  1449032207
#
#                 end_fmt_time   state             label
# 0  2015-12-01T08:49:35-08:00  moving   school_to_train
# 2  2015-12-01T09:40:21-08:00  moving  train_home_train
# 4  2015-12-01T12:20:57-08:00  moving     train_to_soda
# 6  2015-12-01T20:56:47-08:00  moving      soda_to_home

# %%
for idx, row in moving_df.iterrows():
    aa.evaluate_trip_accuracy(iphone_ts_list, android_ts_list, row.label, row.start_ts, row.end_ts)
# Out:
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448986710, '$lt': 1448988575}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 33 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448986710, '$lt': 1448988575}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 99 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448986710, '$lt': 1448988575}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 147 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448986710, '$lt': 1448988575}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 45 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448986710, '$lt': 1448988575}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 46 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448986710, '$lt': 1448988575}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 61 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448986710, '$lt': 1448988575}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448986710, '$lt': 1448988575}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 12 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448986710, '$lt': 1448988575}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 12 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448986710, '$lt': 1448988575}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 3 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448986710, '$lt': 1448988575}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 3 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448986710, '$lt': 1448988575}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 1 results
# Generating trip for school_to_train
# length of lat_means = 3
# DEBUG:root:Caluldated fill_val = 37.3994406463
# Considering phone school_to_train android0
# ground truth exit = 2015-12-01 08:18:30, geofence_exit_ts = +83.533000, first location point = +151.000000
# DEBUG:root:Caluldated fill_val = 37.399494424
# Considering phone school_to_train android1
# ground truth exit = 2015-12-01 08:18:30, geofence_exit_ts = +73.060000, first location point = +105.000000
# Considering phone school_to_train android2
# ground truth exit = 2015-12-01 08:18:30, geofence_exit_ts = +57.667000, first location point = +86.000000
# length of lat_means = 3
# Considering phone school_to_train iphone0
# len(transition_df) = 0, ground_truth_start_ts = 1448986710, geofence was not exited!!
# Considering phone school_to_train iphone1
# ground truth exit = 2015-12-01 08:18:30, geofence_exit_ts = +378.978104, first location point = +435.446784
# Considering phone school_to_train iphone2
# ground truth exit = 2015-12-01 08:18:30, geofence_exit_ts = +344.776468, first location point = +425.721615
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448989467, '$lt': 1448991621}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 18 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448989467, '$lt': 1448991621}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 16 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448989467, '$lt': 1448991621}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 72 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448989467, '$lt': 1448991621}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 36 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448989467, '$lt': 1448991621}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 44 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448989467, '$lt': 1448991621}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 67 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448989467, '$lt': 1448991621}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448989467, '$lt': 1448991621}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 4 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448989467, '$lt': 1448991621}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 16 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448989467, '$lt': 1448991621}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 2 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448989467, '$lt': 1448991621}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 2 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448989467, '$lt': 1448991621}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 1 results
# Generating trip for train_home_train
# length of lat_means = 3
# DEBUG:root:Caluldated fill_val = 37.39253486
# Considering phone train_home_train android0
# ground truth exit = 2015-12-01 09:04:27, geofence_exit_ts = +1804.046000, first location point = +1837.000000
# DEBUG:root:Caluldated fill_val = 37.3926683356
# Considering phone train_home_train android1
# ground truth exit = 2015-12-01 09:04:27, geofence_exit_ts = +1781.262000, first location point = +1813.000000
# Considering phone train_home_train android2
# ground truth exit = 2015-12-01 09:04:27, geofence_exit_ts = +1773.630000, first location point = +1805.000000
# length of lat_means = 3
# Considering phone train_home_train iphone0
# len(transition_df) = 0, ground_truth_start_ts = 1448989467, geofence was not exited!!
# Considering phone train_home_train iphone1
# ground truth exit = 2015-12-01 09:04:27, geofence_exit_ts = +411.533588, first location point = +411.587875
# Considering phone train_home_train iphone2
# ground truth exit = 2015-12-01 09:04:27, geofence_exit_ts = +375.719277, first location point = +375.771916
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448993478, '$lt': 1449001257}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 247 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448993478, '$lt': 1449001257}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 1721 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448993478, '$lt': 1449001257}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 285 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448993478, '$lt': 1449001257}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 235 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448993478, '$lt': 1449001257}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 229 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1448993478, '$lt': 1449001257}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 222 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448993478, '$lt': 1449001257}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448993478, '$lt': 1449001257}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 13 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448993478, '$lt': 1449001257}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 6 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448993478, '$lt': 1449001257}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 2 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448993478, '$lt': 1449001257}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 2 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448993478, '$lt': 1449001257}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# Generating trip for train_to_soda
# length of lat_means = 3
# DEBUG:root:Caluldated fill_val = 37.6673328446
# Considering phone train_to_soda android0
# ground truth exit = 2015-12-01 10:11:18, geofence_exit_ts = +3114.987000, first location point = +3146.000000
# DEBUG:root:Caluldated fill_val = 37.6336197084
# Considering phone train_to_soda android1
# ground truth exit = 2015-12-01 10:11:18, geofence_exit_ts = +3190.943000, first location point = +3198.000000
# Considering phone train_to_soda android2
# len(transition_df) = 0, ground_truth_start_ts = 1448993478, geofence was not exited!!
# length of lat_means = 3
# Considering phone train_to_soda iphone0
# len(transition_df) = 0, ground_truth_start_ts = 1448993478, geofence was not exited!!
# Considering phone train_to_soda iphone1
# len(transition_df) = 13, ground_truth_start_ts = 1448993478, geofence was not exited!!
# Considering phone train_to_soda iphone2
# ground truth exit = 2015-12-01 10:11:18, geofence_exit_ts = +75.791228, first location point = +75.921665
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 279 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 850 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 675 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 267 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 284 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 320 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 19 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 9 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 9 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 6 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# Generating trip for soda_to_home
# length of lat_means = 3
# DEBUG:root:Caluldated fill_val = 37.6744461511
# Considering phone soda_to_home android0
# ground truth exit = 2015-12-01 17:57:53, geofence_exit_ts = +114.429000, first location point = +148.000000
# DEBUG:root:Caluldated fill_val = 37.6235874722
# Considering phone soda_to_home android1
# ground truth exit = 2015-12-01 17:57:53, geofence_exit_ts = +156.909000, first location point = +189.000000
# Considering phone soda_to_home android2
# len(transition_df) = 0, ground_truth_start_ts = 1449021473, geofence was not exited!!
# length of lat_means = 3
# Considering phone soda_to_home iphone0
# len(transition_df) = 0, ground_truth_start_ts = 1449021473, geofence was not exited!!
# Considering phone soda_to_home iphone1
# ground truth exit = 2015-12-01 17:57:53, geofence_exit_ts = +178.414448, first location point = +178.485268
# Considering phone soda_to_home iphone2
# ground truth exit = 2015-12-01 17:57:53, geofence_exit_ts = +192.522071, first location point = +192.574741
# /Users/shankari/OSS/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
import emission.net.usercache.abstract_usercache as enua
android_transition_df_list = [ts.get_data_df("statemachine/transition", enua.UserCache.TimeQuery("write_ts", 1448993478, 1449032207.25)) for ts in android_ts_list]
# Out:
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448993478, '$lt': 1449032207.25}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 20 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448993478, '$lt': 1449032207.25}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 19 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1448993478, '$lt': 1449032207.25}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results

# %%
def evaluate_ios_only(iphone_ts_list, android_ts_list, label):
    import emission.net.usercache.abstract_usercache as enua
    print "Generating trip for %s" % label
    start_0 = moving_df.iloc[-1].start_ts
    end_0 = moving_df.iloc[-1].end_ts

    iphone_0_df_list = [ts.get_data_df("background/location", enua.UserCache.TimeQuery("write_ts", start_0, end_0)) for ts in iphone_ts_list]
    iphone_0_transition_df_list = [ts.get_data_df("statemachine/transition", enua.UserCache.TimeQuery("write_ts", start_0, end_0)) for ts in iphone_ts_list]
    aa.insert_transition_strings(iphone_0_transition_df_list)
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15,2), sharex=True, sharey=True)
    fig.suptitle("%s -> %s" % (pydt.datetime.fromtimestamp(start_0),
                               pydt.datetime.fromtimestamp(end_0)), y = 1.1)
    aa.plot_for_transitions(label + " soda to home ", iphone_0_df_list, iphone_0_transition_df_list, axes, start_0, end_0)
    # return fig

# %%
evaluate_ios_only(iphone_ts_list, android_ts_list, "iphone")
# Out:
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 279 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 850 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 675 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 19 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449021473, '$lt': 1449032207}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 9 results
# Generating trip for iphone
# length of lat_means = 3
# DEBUG:root:Caluldated fill_val = 37.6235874722
# Considering phone iphone soda to home 0
# len(transition_df) = 0, ground_truth_start_ts = 1449021473, geofence was not exited!!
# Considering phone iphone soda to home 1
# ground truth exit = 2015-12-01 17:57:53, geofence_exit_ts = +178.414448, first location point = +178.485268
# Considering phone iphone soda to home 2
# ground truth exit = 2015-12-01 17:57:53, geofence_exit_ts = +192.522071, first location point = +192.574741
