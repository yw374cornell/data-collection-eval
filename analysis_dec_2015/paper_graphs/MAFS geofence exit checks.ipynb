# %%
import sys

# %%
sys.path.insert(0, "../../src/")

# %%
import analysis.common as ac
import analysis.accuracy_eval as aa

# %%
reload(aa)
# Out:
# <module 'analysis.accuracy_eval' from '../../src/analysis/accuracy_eval.pyc'>

# %%
(iphone_ids, android_ids, phone_labels) = ac.setupPaths()

# %%
import emission.core.get_database as edb
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as pydt
import emission.storage.timeseries.abstract_timeseries as esta

# %%
display_names = [ac.get_display_name(label) for label in phone_labels]

# %%
iphone_ts_list = [esta.TimeSeries.get_time_series(id) for id in iphone_ids]
android_ts_list = [esta.TimeSeries.get_time_series(id) for id in android_ids]

# %%
ground_truth_df = pd.read_csv("../../ground_truth/compare_mafs.2015-12-06-07/states.summary")
moving_df = ground_truth_df[ground_truth_df.state == "moving"]
moving_df
# Out:
#     Unnamed: 0  start_index      start_ts           start_fmt_time  \
# 0            0            0  1.449455e+09  2015-12-06 18:24:12.850
# 2            2            3  1.449461e+09  2015-12-06 20:05:49.280
# 5            5            6  1.449505e+09  2015-12-07 08:15:47.930
# 7            7           13  1.449518e+09  2015-12-07 11:53:58.440
# 9            9           19  1.449531e+09  2015-12-07 15:29:44.920
# 11          11           22  1.449536e+09  2015-12-07 16:56:01.680
#
#     start_value  end_index        end_ts             end_fmt_time  end_value  \
# 0           100          1  1.449457e+09  2015-12-06 18:53:54.880        100
# 2           100          4  1.449463e+09  2015-12-06 20:39:32.350        100
# 5            97          7  1.449507e+09  2015-12-07 08:43:18.410         97
# 7            94         14  1.449520e+09  2015-12-07 12:31:22.410         94
# 9            90         21  1.449535e+09  2015-12-07 16:29:18.360         88
# 11           87         23  1.449537e+09  2015-12-07 17:15:47.380         86
#
#      state
# 0   moving
# 2   moving
# 5   moving
# 7   moving
# 9   moving
# 11  moving

# %%
for idx, row in moving_df.iterrows():
    if "label" not in row:
        row.label = ""
    aa.evaluate_trip_accuracy(iphone_ts_list, android_ts_list, row.label, row.start_ts, row.end_ts)
# Out:
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449455052.85, '$lt': 1449456834.88}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449455052.85, '$lt': 1449456834.88}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 2 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449455052.85, '$lt': 1449456834.88}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 62 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449455052.85, '$lt': 1449456834.88}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449455052.85, '$lt': 1449456834.88}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 512 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449455052.85, '$lt': 1449456834.88}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 104 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449455052.85, '$lt': 1449456834.88}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449455052.85, '$lt': 1449456834.88}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449455052.85, '$lt': 1449456834.88}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 4 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449455052.85, '$lt': 1449456834.88}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449455052.85, '$lt': 1449456834.88}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 1 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449455052.85, '$lt': 1449456834.88}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 2 results
# Generating trip for
# length of lat_means = 3
# DEBUG:root:Caluldated fill_val = 37.3892048786
# Considering phone  android0
# No data to plot for dataframe  android0
# Fake data length = 60, fill_val = 37.3892048786
# Considering phone  android1
# DEBUG:root:Caluldated fill_val = 37.3896762073
# len(transition_df) = 1, ground_truth_start_ts = 1449455052, geofence was not exited!!
# Considering phone  android2
# ground truth exit = 2015-12-06 18:24:12.850000, geofence_exit_ts = +1340.572000, first location point = +1348.150000
# length of lat_means = 3
# Considering phone  iphone0
# No data to plot for dataframe  iphone0
# Fake data length = 60, fill_val = 37.3896762073
# Considering phone  iphone1
# len(transition_df) = 0, ground_truth_start_ts = 1449455052, geofence was not exited!!
# Considering phone  iphone2
# ground truth exit = 2015-12-06 18:24:12.850000, geofence_exit_ts = +1291.677857, first location point = +1291.729116
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449461149.28, '$lt': 1449463172.35}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449461149.28, '$lt': 1449463172.35}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 115 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449461149.28, '$lt': 1449463172.35}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 51 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449461149.28, '$lt': 1449463172.35}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449461149.28, '$lt': 1449463172.35}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 267 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449461149.28, '$lt': 1449463172.35}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 235 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449461149.28, '$lt': 1449463172.35}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449461149.28, '$lt': 1449463172.35}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449461149.28, '$lt': 1449463172.35}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 4 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449461149.28, '$lt': 1449463172.35}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449461149.28, '$lt': 1449463172.35}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449461149.28, '$lt': 1449463172.35}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 1 results
# Generating trip for
# length of lat_means = 3
# DEBUG:root:Caluldated fill_val = 37.3901326685
# Considering phone  android0
# No data to plot for dataframe  android0
# Fake data length = 68, fill_val = 37.3901326685
# Considering phone  android1
# DEBUG:root:Caluldated fill_val = 37.3900260626
# len(transition_df) = 0, ground_truth_start_ts = 1449461149, geofence was not exited!!
# Considering phone  android2
# len(transition_df) = 1, ground_truth_start_ts = 1449461149, geofence was not exited!!
# length of lat_means = 3
# Considering phone  iphone0
# No data to plot for dataframe  iphone0
# Fake data length = 68, fill_val = 37.3900260626
# Considering phone  iphone1
# len(transition_df) = 0, ground_truth_start_ts = 1449461149, geofence was not exited!!
# Considering phone  iphone2
# ground truth exit = 2015-12-06 20:05:49.280000, geofence_exit_ts = +815.173809, first location point = +815.220571
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449504947.93, '$lt': 1449506598.41}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449504947.93, '$lt': 1449506598.41}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 217 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449504947.93, '$lt': 1449506598.41}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 65 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449504947.93, '$lt': 1449506598.41}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449504947.93, '$lt': 1449506598.41}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 576 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449504947.93, '$lt': 1449506598.41}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 462 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449504947.93, '$lt': 1449506598.41}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449504947.93, '$lt': 1449506598.41}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449504947.93, '$lt': 1449506598.41}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 4 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449504947.93, '$lt': 1449506598.41}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449504947.93, '$lt': 1449506598.41}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449504947.93, '$lt': 1449506598.41}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 1 results
# Generating trip for
# length of lat_means = 3
# DEBUG:root:Caluldated fill_val = 37.3978893101
# Considering phone  android0
# No data to plot for dataframe  android0
# Fake data length = 56, fill_val = 37.3978893101
# Considering phone  android1
# DEBUG:root:Caluldated fill_val = 37.3964334437
# len(transition_df) = 0, ground_truth_start_ts = 1449504947, geofence was not exited!!
# Considering phone  android2
# ground truth exit = 2015-12-07 08:15:47.930000, geofence_exit_ts = +335.584000, first location point = +343.070000
# length of lat_means = 3
# Considering phone  iphone0
# No data to plot for dataframe  iphone0
# Fake data length = 56, fill_val = 37.3964334437
# Considering phone  iphone1
# len(transition_df) = 0, ground_truth_start_ts = 1449504947, geofence was not exited!!
# Considering phone  iphone2
# ground truth exit = 2015-12-07 08:15:47.930000, geofence_exit_ts = +400.441014, first location point = +1173.592211
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449518038.44, '$lt': 1449520282.41}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449518038.44, '$lt': 1449520282.41}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 132 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449518038.44, '$lt': 1449520282.41}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 65 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449518038.44, '$lt': 1449520282.41}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449518038.44, '$lt': 1449520282.41}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 570 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449518038.44, '$lt': 1449520282.41}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 203 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449518038.44, '$lt': 1449520282.41}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449518038.44, '$lt': 1449520282.41}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449518038.44, '$lt': 1449520282.41}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 6 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449518038.44, '$lt': 1449520282.41}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449518038.44, '$lt': 1449520282.41}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449518038.44, '$lt': 1449520282.41}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 1 results
# Generating trip for
# length of lat_means = 3
# DEBUG:root:Caluldated fill_val = 37.3965337723
# Considering phone  android0
# No data to plot for dataframe  android0
# Fake data length = 75, fill_val = 37.3965337723
# Considering phone  android1
# DEBUG:root:Caluldated fill_val = 37.3984649346
# len(transition_df) = 0, ground_truth_start_ts = 1449518038, geofence was not exited!!
# Considering phone  android2
# ground truth exit = 2015-12-07 11:53:58.440000, geofence_exit_ts = +1578.128000, first location point = +1580.560000
# length of lat_means = 3
# Considering phone  iphone0
# No data to plot for dataframe  iphone0
# Fake data length = 75, fill_val = 37.3984649346
# Considering phone  iphone1
# len(transition_df) = 0, ground_truth_start_ts = 1449518038, geofence was not exited!!
# Considering phone  iphone2
# ground truth exit = 2015-12-07 11:53:58.440000, geofence_exit_ts = +1733.328579, first location point = +1733.375438
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449530984.92, '$lt': 1449534558.36}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449530984.92, '$lt': 1449534558.36}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 287 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449530984.92, '$lt': 1449534558.36}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 281 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449530984.92, '$lt': 1449534558.36}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449530984.92, '$lt': 1449534558.36}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 947 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449530984.92, '$lt': 1449534558.36}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 816 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449530984.92, '$lt': 1449534558.36}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449530984.92, '$lt': 1449534558.36}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449530984.92, '$lt': 1449534558.36}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 6 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449530984.92, '$lt': 1449534558.36}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449530984.92, '$lt': 1449534558.36}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449530984.92, '$lt': 1449534558.36}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 4 results
# Generating trip for
# length of lat_means = 3
# DEBUG:root:Caluldated fill_val = 37.4024313702
# Considering phone  android0
# No data to plot for dataframe  android0
# Fake data length = 120, fill_val = 37.4024313702
# Considering phone  android1
# len(transition_df) = 0, ground_truth_start_ts = 1449530984, geofence was not exited!!
# Considering phone  android2
# ground truth exit = 2015-12-07 15:29:44.920000, geofence_exit_ts = +319.042000, first location point = +379.080000
# DEBUG:root:Caluldated fill_val = 37.4024655702
# length of lat_means = 3
# Considering phone  iphone0
# No data to plot for dataframe  iphone0
# Fake data length = 120, fill_val = 37.4024655702
# Considering phone  iphone1
# len(transition_df) = 0, ground_truth_start_ts = 1449530984, geofence was not exited!!
# Considering phone  iphone2
# ground truth exit = 2015-12-07 15:29:44.920000, geofence_exit_ts = +289.925957, first location point = +290.202021
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449536161.68, '$lt': 1449537347.38}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449536161.68, '$lt': 1449537347.38}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 130 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449536161.68, '$lt': 1449537347.38}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 131 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449536161.68, '$lt': 1449537347.38}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449536161.68, '$lt': 1449537347.38}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 295 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'background/location'}], 'metadata.write_ts': {'$gte': 1449536161.68, '$lt': 1449537347.38}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 40 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449536161.68, '$lt': 1449537347.38}, 'user_id': UUID('079e0f1a-c440-3d7c-b0e7-de160f748e35')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449536161.68, '$lt': 1449537347.38}, 'user_id': UUID('c76a0487-7e5a-3b17-a449-47be666b36f6')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449536161.68, '$lt': 1449537347.38}, 'user_id': UUID('c528bcd2-a88b-3e82-be62-ef4f2396967a')}, sort_key = metadata.write_ts
# DEBUG:root:Found 2 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449536161.68, '$lt': 1449537347.38}, 'user_id': UUID('e471711e-bd14-3dbe-80b6-9c7d92ecc296')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449536161.68, '$lt': 1449537347.38}, 'user_id': UUID('fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7')}, sort_key = metadata.write_ts
# DEBUG:root:Found 0 results
# DEBUG:root:curr_query = {'$or': [{'metadata.key': 'statemachine/transition'}], 'metadata.write_ts': {'$gte': 1449536161.68, '$lt': 1449537347.38}, 'user_id': UUID('86842c35-da28-32ed-a90e-2da6663c5c73')}, sort_key = metadata.write_ts
# DEBUG:root:Found 1 results
# Generating trip for
# length of lat_means = 3
# DEBUG:root:Caluldated fill_val = 37.3957991895
# Considering phone  android0
# No data to plot for dataframe  android0
# Fake data length = 40, fill_val = 37.3957991895
# Considering phone  android1
# DEBUG:root:Caluldated fill_val = 37.4057393321
# len(transition_df) = 0, ground_truth_start_ts = 1449536161, geofence was not exited!!
# Considering phone  android2
# ground truth exit = 2015-12-07 16:56:01.680000, geofence_exit_ts = +971.437000, first location point = +972.320000
# length of lat_means = 3
# Considering phone  iphone0
# No data to plot for dataframe  iphone0
# Fake data length = 40, fill_val = 37.4057393321
# Considering phone  iphone1
# len(transition_df) = 0, ground_truth_start_ts = 1449536161, geofence was not exited!!
# Considering phone  iphone2
# len(transition_df) = 2, ground_truth_start_ts = 1449536161, geofence was not exited!!
# /Users/shankari/OSS/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
