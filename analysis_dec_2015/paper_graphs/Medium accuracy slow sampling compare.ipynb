# %%
import sys

# %%
sys.path.insert(0, "../../src/")

# %%
import analysis.common as ac
import analysis.power_drain_manual as ap

# %%
reload(ap)
# Out:
# <module 'analysis.power_drain_manual' from '../../src/analysis/power_drain_manual.pyc'>

# %%
(iphone_ids, android_ids, phone_labels) = ac.setupPaths()

# %%
import emission.core.get_database as edb
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as pydt

# %%
display_names = [ac.get_display_name(label) for label in phone_labels]

# %%
drain_df_map = {}

# %%
drain_df_map["ios.1"] = pd.read_csv("../../results_dec_2015/ucb.sdb.ios.1/power_logs/nd_manual_1449558060.log")
drain_df_map["ios.2"] = pd.read_csv("../../results_dec_2015/ucb.sdb.ios.2/power_logs/ma100m_manual_1449558060.log")
drain_df_map["ios.3"] = pd.read_csv("../../results_dec_2015/ucb.sdb.ios.3/power_logs/geo100m-ma100m_manual_1449558060.log")

# %%
drain_df_map["android.1"] = pd.read_csv("../../results_dec_2015/ucb.sdb.android.1/power_logs/nd_manual_1449558060.log")
drain_df_map["android.2"] = pd.read_csv("../../results_dec_2015/ucb.sdb.android.2/power_logs/ma30s_manual_1449558060.log")
drain_df_map["android.3"] = pd.read_csv("../../results_dec_2015/ucb.sdb.android.3/power_logs/geo100m-ma30s_manual_1449558060.log")

# %%
regime_map = {}

# %%
regime_map["ios.1"] = "nd"
regime_map["ios.2"] = "mass"
regime_map["ios.3"] = "geo-mass"

# %%
regime_map["android.1"] = "nd"
regime_map["android.2"] = "mass"
regime_map["android.3"] = "geo-mass"

# %%
for drain_df in drain_df_map.values():
    drain_df["fmt_time"] = drain_df.ts.map(lambda(t): pydt.datetime.fromtimestamp(t))

# %%
drain_df
# Out:
#               key            ts  value                fmt_time
# 0   battery_level  1.449558e+09    100 2015-12-07 23:01:00.770
# 1   battery_level  1.449602e+09     99 2015-12-08 11:08:15.130
# 2   battery_level  1.449603e+09     99 2015-12-08 11:33:26.020
# 3   battery_level  1.449605e+09     98 2015-12-08 12:06:20.370
# 4   battery_level  1.449608e+09     97 2015-12-08 12:56:31.850
# 5   battery_level  1.449610e+09     96 2015-12-08 13:31:22.990
# 6   battery_level  1.449612e+09     95 2015-12-08 14:03:09.230
# 7   battery_level  1.449614e+09     93 2015-12-08 14:39:27.260
# 8   battery_level  1.449618e+09     90 2015-12-08 15:38:06.280
# 9   battery_level  1.449620e+09     88 2015-12-08 16:07:10.600
# 10  battery_level  1.449622e+09     86 2015-12-08 16:42:02.650
# 11  battery_level  1.449625e+09     84 2015-12-08 17:35:44.340
# 12  battery_level  1.449627e+09     84 2015-12-08 18:14:42.610
# 13  battery_level  1.449629e+09     84 2015-12-08 18:36:25.420
# ...

# %%
drain_df_map['android.1']
# Out:
#               key            ts  value                fmt_time
# 0   battery_level  1.449558e+09    100 2015-12-07 23:01:00.770
# 1   battery_level  1.449602e+09     97 2015-12-08 11:08:15.130
# 2   battery_level  1.449603e+09     97 2015-12-08 11:33:26.020
# 3   battery_level  1.449605e+09     97 2015-12-08 12:06:20.370
# 4   battery_level  1.449608e+09     96 2015-12-08 12:56:31.850
# 5   battery_level  1.449610e+09     96 2015-12-08 13:31:22.990
# 6   battery_level  1.449612e+09     96 2015-12-08 14:03:09.230
# 7   battery_level  1.449614e+09     95 2015-12-08 14:39:27.260
# 8   battery_level  1.449618e+09     95 2015-12-08 15:38:06.280
# 9   battery_level  1.449620e+09     95 2015-12-08 16:07:10.600
# 10  battery_level  1.449622e+09     94 2015-12-08 16:42:02.650
# 11  battery_level  1.449625e+09     94 2015-12-08 17:35:44.340
# 12  battery_level  1.449627e+09     94 2015-12-08 18:14:42.610
# 13  battery_level  1.449629e+09     93 2015-12-08 18:36:25.420
# ...

# %%
ground_truth_df = ap.get_ground_truth_df(drain_df, [[0,1,3,4,5,8,19], 
                                                    ["passive", "active", "moving", "active", "moving", "active"]])
ground_truth_df.to_csv("../../ground_truth/compare_mass.2015-12-06-08/states.summary")

# %%
ground_truth_df
# Out:
#    start_index      start_ts          start_fmt_time  start_value  end_index  \
# 0            0  1.449558e+09 2015-12-07 23:01:00.770          100          1
# 1            1  1.449602e+09 2015-12-08 11:08:15.130           99          3
# 2            3  1.449605e+09 2015-12-08 12:06:20.370           98          4
# 3            4  1.449608e+09 2015-12-08 12:56:31.850           97          5
# 4            5  1.449610e+09 2015-12-08 13:31:22.990           96          8
# 5            8  1.449618e+09 2015-12-08 15:38:06.280           90         19
#
#          end_ts            end_fmt_time  end_value    state
# 0  1.449602e+09 2015-12-08 11:08:15.130         99  passive
# 1  1.449605e+09 2015-12-08 12:06:20.370         98   active
# 2  1.449608e+09 2015-12-08 12:56:31.850         97   moving
# 3  1.449610e+09 2015-12-08 13:31:22.990         96   active
# 4  1.449618e+09 2015-12-08 15:38:06.280         90   moving
# 5  1.449645e+09 2015-12-08 23:13:11.720         80   active

# %%
drain_df_map.keys()
# Out:
# ['android.2', 'android.3', 'android.1', 'ios.1', 'ios.2', 'ios.3']

# %%
ap.display_drain_over_day(drain_df_map, ground_truth_df, regime_map)
# Out:
# adding annotations for 0, 2015-12-07 23:01:00.770000, 2015-12-08 11:08:15.130000
# adding annotations for 1, 2015-12-08 11:08:15.130000, 2015-12-08 12:06:20.370000
# adding annotations for 2, 2015-12-08 12:06:20.370000, 2015-12-08 12:56:31.850000
# adding annotations for 3, 2015-12-08 12:56:31.850000, 2015-12-08 13:31:22.990000
# adding annotations for 4, 2015-12-08 13:31:22.990000, 2015-12-08 15:38:06.280000
# adding annotations for 5, 2015-12-08 15:38:06.280000, 2015-12-08 23:13:11.720000
# adding annotations for 0, 2015-12-07 23:01:00.770000, 2015-12-08 11:08:15.130000
# adding annotations for 1, 2015-12-08 11:08:15.130000, 2015-12-08 12:06:20.370000
# adding annotations for 2, 2015-12-08 12:06:20.370000, 2015-12-08 12:56:31.850000
# adding annotations for 3, 2015-12-08 12:56:31.850000, 2015-12-08 13:31:22.990000
# adding annotations for 4, 2015-12-08 13:31:22.990000, 2015-12-08 15:38:06.280000
# adding annotations for 5, 2015-12-08 15:38:06.280000, 2015-12-08 23:13:11.720000
# ...

# %%
ap.display_per_state_drain(drain_df_map, ground_truth_df, regime_map)
# Out:
# displaying 0, android.1 (nd)
# displaying 1, android.2 (mass)
# displaying 2, android.3 (geo-mass)
# displaying 3, ios.1 (nd)
# displaying 4, ios.2 (mass)
# displaying 5, ios.3 (geo-mass)
# (<matplotlib.figure.Figure at 0x10a01c250>,
#  array([<matplotlib.axes.AxesSubplot object at 0x10a003c90>,
# ...
#         <matplotlib.axes.AxesSubplot object at 0x10a75a190>], dtype=object))

# %%
state_diff_df_map = {}
for i, key in enumerate(sorted(drain_df_map.keys())):
    print "displaying %d, %s (%s)" % (i, key, regime_map[key])
    state_diff_df_map[key] = ap.get_state_diff_df(drain_df_map[key], ground_truth_df)
    print state_diff_df_map[key].groupby('state').rate.describe()
# Out:
# displaying 0, android.1 (nd)
# state
# active   count    14.000000
#          mean     -0.474929
#          std       0.881806
#          min      -2.763258
#          25%      -0.509003
#          50%       0.000000
#          75%       0.000000
#          max       0.000000
# moving   count     4.000000
#          mean     -0.712074
#          std       0.843173
#          min      -1.652870
#          25%      -1.309787
#          50%      -0.597713
#          75%       0.000000
#          max       0.000000
# passive  count     1.000000
#          mean     -0.247511
#          std            NaN
#          min      -0.247511
#          25%      -0.247511
#          50%      -0.247511
#          75%      -0.247511
#          max      -0.247511
# dtype: float64
# displaying 1, android.2 (mass)
# state
# active   count    14.000000
#          mean     -0.748173
#          std       0.986722
#          min      -2.727190
#          25%      -1.675500
#          50%       0.000000
# ...
