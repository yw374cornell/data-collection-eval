# %%
import sys

# %%
sys.path.insert(0, "/Users/shankari/e-mission/data-collection-eval/src")

# %%
sys.path
# Out:
# ['/Users/shankari/e-mission/data-collection-eval/src',
#  '',
#  '/Users/shankari/OSS/anaconda/lib/python2.7/site-packages/pygmaps-0.1.1-py2.7.egg',
#  '/Users/shankari/bin/python',
#  '/Users/shankari/e-mission/data-collection-eval/analysis_dec_2015/maps',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python27.zip',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/plat-darwin',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/plat-mac',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/plat-mac/lib-scriptpackages',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/lib-tk',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/lib-old',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/lib-dynload',
#  '/Users/shankari/OSS/anaconda/lib/python2.7/site-packages',
# ...

# %%
import analysis.common as ac

# %%
(iphone_ids, android_ids, phone_labels) = ac.setupPaths()

# %%
import emission.analysis.plotting.geojson.geojson_feature_converter as gfc
import emission.analysis.plotting.leaflet_osm.our_plotter as lo
import emission.analysis.plotting.leaflet_osm.ipython_helper as ipy

# %%
import emission.core.get_database as edb
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as pydt

# %%
ground_truth_df = pd.read_csv("../../ground_truth/geofence_exit_triggers.thu.2015-12-03/states.summary")

# %%
moving_df = ground_truth_df[ground_truth_df.state == "moving"]
moving_df
# Out:
#      start_ts             start_fmt_time      end_ts  \
# 0  1449174317  2015-12-03T12:25:17-08:00  1449176691
# 2  1449186063  2015-12-03T15:41:03-08:00  1449186355
# 4  1449189353  2015-12-03T16:35:53-08:00  1449189707
# 6  1449193436  2015-12-03T17:43:56-08:00  1449194102
# 8  1449202323  2015-12-03T20:12:03-08:00  1449203103
#
#                 end_fmt_time   state
# 0  2015-12-03T13:04:51-08:00  moving
# 2  2015-12-03T15:45:55-08:00  moving
# 4  2015-12-03T16:41:47-08:00  moving
# 6  2015-12-03T17:55:02-08:00  moving
# 8  2015-12-03T20:25:03-08:00  moving

# %%
ipy.inline_maps([lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[0], "background/location", moving_df.iloc[0].start_ts, moving_df.iloc[0].end_ts)]) +
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[1], "background/location", moving_df.iloc[0].start_ts, moving_df.iloc[0].end_ts)]) + 
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[2], "background/location", moving_df.iloc[0].start_ts, moving_df.iloc[0].end_ts)])])
# Out:
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:Getting midpoint of (-122.0863323659842, 37.39106453958656) and (-122.086556498075, 37.39102715629841)
# DEBUG:root:sort_key = metadata.write_ts
# Found 577 points
# Found 463 points
# DEBUG:root:Getting midpoint of (-122.0814937142462, 37.39978619244853) and (-122.0865181089585, 37.39108029756452)
# DEBUG:root:sort_key = metadata.write_ts
# Found 285 points
# DEBUG:root:Getting midpoint of (-122.0849592493336, 37.40102881919377) and (-122.0866139979307, 37.391051170451)
# map_list = [[<folium.folium.Map object at 0x10e5c0f50>, <folium.folium.Map object at 0x10eaa4350>, <folium.folium.Map object at 0x10c40ee50>]]
# <iframe srcdoc="<table width=&quot;100%&quot;>
# <tr><td>&lt;iframe srcdoc=&quot;&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#    &lt;meta http-equiv=&amp;quot;content-type&amp;quot; content=&amp;quot;text/html; charset=UTF-8&amp;quot; /&gt;
# ...

# %% [markdown]
# Having the round trip here makes it confusing to see when the trip started. Let's look at only the part going there, which ends at 1449145962 according to the photographic record.

# %%
ipy.inline_maps([lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[0], "background/location", moving_df.iloc[0].start_ts, 1449174762)]) +
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[1], "background/location", moving_df.iloc[0].start_ts, 1449174762)]) + 
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[2], "background/location", moving_df.iloc[0].start_ts, 1449174762)])])
# Out:
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:Getting midpoint of (-122.0863323659842, 37.39106453958656) and (-122.0845965576564, 37.40347838964071)
# DEBUG:root:sort_key = metadata.write_ts
# Found 259 points
# Found 98 points
# DEBUG:root:Getting midpoint of (-122.0814937142462, 37.39978619244853) and (-122.0845512953793, 37.40344674795624)
# DEBUG:root:sort_key = metadata.write_ts
# Found 0 points
# map_list = [[<folium.folium.Map object at 0x10ea06290>, <folium.folium.Map object at 0x10ea06790>, <folium.folium.Map object at 0x10e59ff10>]]
# <iframe srcdoc="<table width=&quot;100%&quot;>
# <tr><td>&lt;iframe srcdoc=&quot;&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#    &lt;meta http-equiv=&amp;quot;content-type&amp;quot; content=&amp;quot;text/html; charset=UTF-8&amp;quot; /&gt;
#    &lt;link rel=&amp;quot;stylesheet&amp;quot; href=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&amp;quot; /&gt;
# ...

# %%
ipy.inline_maps([lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[0], "background/location", moving_df.iloc[-1].start_ts, moving_df.iloc[-1].end_ts)]) +
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[1], "background/location", moving_df.iloc[-1].start_ts, moving_df.iloc[-1].end_ts)]) + 
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[2], "background/location", moving_df.iloc[-1].start_ts, moving_df.iloc[-1].end_ts)])])
# Out:
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:Getting midpoint of (-122.086469242463, 37.39100695591177) and (-122.0864657220636, 37.3910379689535)
# DEBUG:root:sort_key = metadata.write_ts
# Found 307 points
# Found 286 points
# DEBUG:root:Getting midpoint of (-122.0859809127842, 37.39157495558019) and (-122.0864339546506, 37.3910675570717)
# DEBUG:root:sort_key = metadata.write_ts
# Found 202 points
# DEBUG:root:Getting midpoint of (-122.0843435918187, 37.39346377555038) and (-122.0863913528876, 37.3904607380026)
# map_list = [[<folium.folium.Map object at 0x10c40e190>, <folium.folium.Map object at 0x10e5c0fd0>, <folium.folium.Map object at 0x10e860610>]]
# <iframe srcdoc="<table width=&quot;100%&quot;>
# <tr><td>&lt;iframe srcdoc=&quot;&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#    &lt;meta http-equiv=&amp;quot;content-type&amp;quot; content=&amp;quot;text/html; charset=UTF-8&amp;quot; /&gt;
# ...
