# %%
import sys

# %%
sys.path.insert(0, "/Users/shankari/e-mission/e-mission-server/")

# %%
sys.path
# Out:
# ['/Users/shankari/e-mission/e-mission-server/',
#  '',
#  '/Users/shankari/OSS/anaconda/lib/python2.7/site-packages/pygmaps-0.1.1-py2.7.egg',
#  '/Users/shankari/bin/python',
#  '/Users/shankari/e-mission/data-collection-eval/analysis_dec_2015',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python27.zip',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/plat-darwin',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/plat-mac',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/plat-mac/lib-scriptpackages',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/lib-tk',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/lib-old',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/lib-dynload',
#  '/Users/shankari/OSS/anaconda/lib/python2.7/site-packages',
# ...

# %%
import emission.analysis.plotting.geojson.geojson_feature_converter as gfc
import emission.analysis.plotting.leaflet_osm.our_plotter as lo
import emission.analysis.plotting.leaflet_osm.ipython_helper as ipy

# %%
import logging
logging.getLogger().setLevel(logging.DEBUG)

# %%
from uuid import UUID

# %%
iphone_ids = [UUID("079e0f1a-c440-3d7c-b0e7-de160f748e35"), UUID("c76a0487-7e5a-3b17-a449-47be666b36f6"), UUID("c528bcd2-a88b-3e82-be62-ef4f2396967a")]
android_ids = [UUID("e471711e-bd14-3dbe-80b6-9c7d92ecc296"), UUID("fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7"), UUID("86842c35-da28-32ed-a90e-2da6663c5c73")]

# %%
import emission.core.get_database as edb

# %%
edb.get_timeseries_db().find({'user_id': iphone_ids[0]}).count()
# Out:
# 6404

# %%
edb.get_timeseries_db().find({'user_id': iphone_ids[0], 'metadata.key': 'background/location'}).count()
# Out:
# 236

# %%
edb.get_timeseries_db().find({'user_id': iphone_ids[0], 'metadata.key': 'background/location', "metadata.write_ts": {"$gte": 1448647200}}).count()
# Out:
# 108

# %%
edb.get_timeseries_db().find({'user_id': iphone_ids[0], 'metadata.key': 'background/filtered_location'}).count()
# Out:
# 99

# %%
ipy.inline_maps([
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[0], "background/location", 1448465466, 1448510988)]),
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[1], "background/location", 1448465466, 1448510988)]),
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[2], "background/location", 1448465466, 1448510988)])])
# Out:
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:Getting midpoint of (-122.0825354802744, 37.39081095521095) and (-122.0861932046645, 37.39094528052383)
# DEBUG:root:sort_key = metadata.write_ts
# Found 128 points
# Found 108 points
# DEBUG:root:Getting midpoint of (-122.0862823907867, 37.39086917303393) and (-122.0865051170085, 37.39046971782799)
# DEBUG:root:sort_key = metadata.write_ts
# Found 0 points
# <iframe srcdoc="<table width=&quot;100%&quot;>
# <tr><td>&lt;iframe srcdoc=&quot;&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#    &lt;meta http-equiv=&amp;quot;content-type&amp;quot; content=&amp;quot;text/html; charset=UTF-8&amp;quot; /&gt;
#    &lt;link rel=&amp;quot;stylesheet&amp;quot; href=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&amp;quot; /&gt;
#    &lt;script src=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&amp;quot;&gt;&lt;/script&gt;
#
# ...

# %%
ipy.inline_maps([
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[0], "background/filtered_location", 1448465466, 1448510988)]),
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[1], "background/filtered_location", 1448465466, 1448510988)]),
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[2], "background/filtered_location", 1448465466, 1448510988)])])
# Out:
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:Getting midpoint of (-122.0825354802744, 37.39081095521095) and (-122.0861932046645, 37.39094528052383)
# DEBUG:root:sort_key = metadata.write_ts
# Found 71 points
# Found 101 points
# DEBUG:root:Getting midpoint of (-122.0862823907867, 37.39086917303393) and (-122.0865051170085, 37.39046971782799)
# DEBUG:root:sort_key = metadata.write_ts
# Found 0 points
# <iframe srcdoc="<table width=&quot;100%&quot;>
# <tr><td>&lt;iframe srcdoc=&quot;&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#    &lt;meta http-equiv=&amp;quot;content-type&amp;quot; content=&amp;quot;text/html; charset=UTF-8&amp;quot; /&gt;
#    &lt;link rel=&amp;quot;stylesheet&amp;quot; href=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&amp;quot; /&gt;
#    &lt;script src=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&amp;quot;&gt;&lt;/script&gt;
#
# ...

# %%
ipy.inline_maps([
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[0], "background/location", 1448647200, 1448683987)]),
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[1], "background/location", 1448647200, 1448683987)]),
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[2], "background/location", 1448647200, 1448683987)])])
# Out:
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:Getting midpoint of (-122.0842853187795, 37.38926894782901) and (-122.086371986729, 37.39099554956432)
# DEBUG:root:sort_key = metadata.write_ts
# Found 108 points
# Found 65 points
# DEBUG:root:Getting midpoint of (-122.0856593829785, 37.38985884472485) and (-122.086301359465, 37.39080199582808)
# DEBUG:root:sort_key = metadata.write_ts
# Found 0 points
# <iframe srcdoc="<table width=&quot;100%&quot;>
# <tr><td>&lt;iframe srcdoc=&quot;&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#    &lt;meta http-equiv=&amp;quot;content-type&amp;quot; content=&amp;quot;text/html; charset=UTF-8&amp;quot; /&gt;
#    &lt;link rel=&amp;quot;stylesheet&amp;quot; href=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&amp;quot; /&gt;
#    &lt;script src=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&amp;quot;&gt;&lt;/script&gt;
#
# ...

# %%
ipy.inline_maps([
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[0], "background/filtered_location", 1448647200, 1448683987)]),
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[1], "background/filtered_location", 1448647200, 1448683987)]),
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[2], "background/filtered_location", 1448647200, 1448683987)])])
# Out:
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:Getting midpoint of (-122.0842853187795, 37.38926894782901) and (-122.086371986729, 37.39099554956432)
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:Getting midpoint of (-122.0856593829785, 37.38985884472485) and (-122.086301359465, 37.39080199582808)
# DEBUG:root:sort_key = metadata.write_ts
# Found 28 points
# Found 33 points
# Found 0 points
# <iframe srcdoc="<table width=&quot;100%&quot;>
# <tr><td>&lt;iframe srcdoc=&quot;&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#    &lt;meta http-equiv=&amp;quot;content-type&amp;quot; content=&amp;quot;text/html; charset=UTF-8&amp;quot; /&gt;
#    &lt;link rel=&amp;quot;stylesheet&amp;quot; href=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&amp;quot; /&gt;
#    &lt;script src=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&amp;quot;&gt;&lt;/script&gt;
#
# ...

# %%
ipy.inline_maps([
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[0], "background/location", 1448647200, 1448683987)]),
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[1], "background/location", 1448647200, 1448683987)]),
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[2], "background/location", 1448647200, 1448683987)])])
# Out:
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:Getting midpoint of (-122.0864666, 37.39103407) and (-122.08646927, 37.39098772)
# DEBUG:root:sort_key = metadata.write_ts
# Found 764 points
# Found 227 points
# DEBUG:root:Getting midpoint of (-122.0851426, 37.3898778) and (-122.0862143, 37.391011)
# DEBUG:root:sort_key = metadata.write_ts
# Found 0 points
# <iframe srcdoc="<table width=&quot;100%&quot;>
# <tr><td>&lt;iframe srcdoc=&quot;&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#    &lt;meta http-equiv=&amp;quot;content-type&amp;quot; content=&amp;quot;text/html; charset=UTF-8&amp;quot; /&gt;
#    &lt;link rel=&amp;quot;stylesheet&amp;quot; href=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&amp;quot; /&gt;
#    &lt;script src=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&amp;quot;&gt;&lt;/script&gt;
#
#    &lt;script src=&amp;quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&amp;quot;&gt;&lt;/script&gt;
#
# ...

# %%
ipy.inline_maps([
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[0], "background/filtered_location", 1448640762, 1448688775)]),
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[1], "background/filtered_location", 1448640762, 1448688775)]),
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[2], "background/filtered_location", 1448640762, 1448688775)])])
# Out:
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:Getting midpoint of (-122.08645402, 37.39111843) and (-122.08646859, 37.3909855)
# DEBUG:root:sort_key = metadata.write_ts
# Found 986 points
# Found 235 points
# DEBUG:root:Getting midpoint of (-122.0862314, 37.3909822) and (-122.0862143, 37.391011)
# DEBUG:root:sort_key = metadata.write_ts
# Found 0 points
# <iframe srcdoc="<table width=&quot;100%&quot;>
# <tr><td>&lt;iframe srcdoc=&quot;&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#    &lt;meta http-equiv=&amp;quot;content-type&amp;quot; content=&amp;quot;text/html; charset=UTF-8&amp;quot; /&gt;
#    &lt;link rel=&amp;quot;stylesheet&amp;quot; href=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&amp;quot; /&gt;
#    &lt;script src=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&amp;quot;&gt;&lt;/script&gt;
#
#    &lt;script src=&amp;quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&amp;quot;&gt;&lt;/script&gt;
#
# ...

# %%
ipy.inline_maps([
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[0], "background/location", 1448726862, 1448750731)]),
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[1], "background/location", 1448726862, 1448750731)]),
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[2], "background/location", 1448726862, 1448750731)])])
# Out:
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:Getting midpoint of (-122.08640216, 37.39111244) and (-122.08655478, 37.39105662)
# DEBUG:root:sort_key = metadata.write_ts
# Found 534 points
# Found 96 points
# DEBUG:root:Getting midpoint of (-122.098345, 37.3954905) and (-122.0862133, 37.3910302)
# DEBUG:root:sort_key = metadata.write_ts
# Found 0 points
# <iframe srcdoc="<table width=&quot;100%&quot;>
# <tr><td>&lt;iframe srcdoc=&quot;&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#    &lt;meta http-equiv=&amp;quot;content-type&amp;quot; content=&amp;quot;text/html; charset=UTF-8&amp;quot; /&gt;
#    &lt;link rel=&amp;quot;stylesheet&amp;quot; href=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&amp;quot; /&gt;
#    &lt;script src=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&amp;quot;&gt;&lt;/script&gt;
#
#    &lt;script src=&amp;quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&amp;quot;&gt;&lt;/script&gt;
#
# ...
