# %%
import sys

# %%
sys.path.insert(0, "/Users/shankari/e-mission/data-collection-eval/src")

# %%
sys.path
# Out:
# ['/Users/shankari/e-mission/data-collection-eval/src',
#  '',
#  '/Users/shankari/OSS/anaconda/lib/python2.7/site-packages/pygmaps-0.1.1-py2.7.egg',
#  '/Users/shankari/bin/python',
#  '/Users/shankari/e-mission/data-collection-eval/analysis_dec_2015/maps',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python27.zip',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/plat-darwin',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/plat-mac',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/plat-mac/lib-scriptpackages',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/lib-tk',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/lib-old',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/lib-dynload',
#  '/Users/shankari/OSS/anaconda/lib/python2.7/site-packages',
# ...

# %%
import analysis.common as ac

# %%
(iphone_ids, android_ids, phone_labels) = ac.setupPaths()

# %%
import emission.analysis.plotting.geojson.geojson_feature_converter as gfc
import emission.analysis.plotting.leaflet_osm.our_plotter as lo
import emission.analysis.plotting.leaflet_osm.ipython_helper as ipy

# %%
import emission.core.get_database as edb
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as pydt

# %%
ground_truth_df = pd.read_csv("../../ground_truth/compare_mafs.2015-12-06-07/states.summary")

# %%
moving_df = ground_truth_df[ground_truth_df.state == "moving"]
moving_df
# Out:
#     Unnamed: 0  start_index      start_ts           start_fmt_time  \
# 0            0            0  1.449455e+09  2015-12-06 18:24:12.850
# 2            2            3  1.449461e+09  2015-12-06 20:05:49.280
# 5            5            6  1.449505e+09  2015-12-07 08:15:47.930
# 7            7           13  1.449518e+09  2015-12-07 11:53:58.440
# 9            9           19  1.449531e+09  2015-12-07 15:29:44.920
# 11          11           22  1.449536e+09  2015-12-07 16:56:01.680
#
#     start_value  end_index        end_ts             end_fmt_time  end_value  \
# 0           100          1  1.449457e+09  2015-12-06 18:53:54.880        100
# 2           100          4  1.449463e+09  2015-12-06 20:39:32.350        100
# 5            97          7  1.449507e+09  2015-12-07 08:43:18.410         97
# 7            94         14  1.449520e+09  2015-12-07 12:31:22.410         94
# 9            90         21  1.449535e+09  2015-12-07 16:29:18.360         88
# ...

# %%
ipy.inline_maps([lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[0], "background/location", moving_df.iloc[0].start_ts, moving_df.iloc[0].end_ts)]) +
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[1], "background/location", moving_df.iloc[0].start_ts, moving_df.iloc[0].end_ts)]) + 
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[2], "background/location", moving_df.iloc[0].start_ts, moving_df.iloc[0].end_ts)])])
# Out:
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:Getting midpoint of (-122.0864611120169, 37.39101969640459) and (-122.0864448511247, 37.39101802002396)
# DEBUG:root:sort_key = metadata.write_ts
# Found 0 points
# Found 2 points
# Found 62 points
# DEBUG:root:Getting midpoint of (-122.0864580107127, 37.39101596645768) and (-122.088715493002, 37.38810172456019)
# map_list = [[<folium.folium.Map object at 0x10e768710>, <folium.folium.Map object at 0x10e768e90>, <folium.folium.Map object at 0x10e79a910>]]
# <iframe srcdoc="<table width=&quot;100%&quot;>
# <tr><td>&lt;iframe srcdoc=&quot;&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#    &lt;meta http-equiv=&amp;quot;content-type&amp;quot; content=&amp;quot;text/html; charset=UTF-8&amp;quot; /&gt;
#    &lt;link rel=&amp;quot;stylesheet&amp;quot; href=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&amp;quot; /&gt;
# ...

# %%
ipy.inline_maps([lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[0], "background/location", moving_df.iloc[1].start_ts, moving_df.iloc[1].end_ts)]) +
                 lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[1], "background/location", moving_df.iloc[1].start_ts, moving_df.iloc[1].end_ts)]) + 
                 lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[2], "background/location", moving_df.iloc[1].start_ts, moving_df.iloc[1].end_ts)])])
# Out:
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:Getting midpoint of (-122.0886245182458, 37.38806380535259) and (-122.0865646528348, 37.39089647893854)
# DEBUG:root:sort_key = metadata.write_ts
# Found 0 points
# Found 115 points
# Found 51 points
# DEBUG:root:Getting midpoint of (-122.0864580107127, 37.39101596645768) and (-122.0863582294736, 37.39066461082614)
# map_list = [[<folium.folium.Map object at 0x10c4105d0>, <folium.folium.Map object at 0x10c410b90>, <folium.folium.Map object at 0x10e79a710>]]
# <iframe srcdoc="<table width=&quot;100%&quot;>
# <tr><td>&lt;iframe srcdoc=&quot;&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#    &lt;meta http-equiv=&amp;quot;content-type&amp;quot; content=&amp;quot;text/html; charset=UTF-8&amp;quot; /&gt;
#    &lt;link rel=&amp;quot;stylesheet&amp;quot; href=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&amp;quot; /&gt;
# ...

# %%
ipy.inline_maps([lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[0], "background/location", moving_df.iloc[0].start_ts, moving_df.iloc[0].end_ts)]) +
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[1], "background/location", moving_df.iloc[0].start_ts, moving_df.iloc[0].end_ts)]) + 
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[2], "background/location", moving_df.iloc[0].start_ts, moving_df.iloc[0].end_ts)])])
# Out:
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:sort_key = metadata.write_ts
# Found 0 points
# Found 512 points
# DEBUG:root:Getting midpoint of (-122.0864783, 37.3910349) and (-122.08903237, 37.38785595)
# DEBUG:root:sort_key = metadata.write_ts
# Found 104 points
# DEBUG:root:Getting midpoint of (-122.08749717, 37.38956949) and (-122.08901138, 37.38778794)
# map_list = [[<folium.folium.Map object at 0x10e79ab10>, <folium.folium.Map object at 0x10c43eb90>, <folium.folium.Map object at 0x10e7a75d0>]]
# <iframe srcdoc="<table width=&quot;100%&quot;>
# <tr><td>&lt;iframe srcdoc=&quot;&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#    &lt;meta http-equiv=&amp;quot;content-type&amp;quot; content=&amp;quot;text/html; charset=UTF-8&amp;quot; /&gt;
#    &lt;link rel=&amp;quot;stylesheet&amp;quot; href=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&amp;quot; /&gt;
# ...

# %%
ipy.inline_maps([lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[0], "background/location", moving_df.iloc[1].start_ts, moving_df.iloc[1].end_ts)]) +
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[1], "background/location", moving_df.iloc[1].start_ts, moving_df.iloc[1].end_ts)]) + 
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[2], "background/location", moving_df.iloc[1].start_ts, moving_df.iloc[1].end_ts)])])
# Out:
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:Getting midpoint of (-122.0882431, 37.3879356) and (-122.0862457, 37.3908918)
# DEBUG:root:sort_key = metadata.write_ts
# Found 0 points
# Found 267 points
# Found 235 points
# DEBUG:root:Getting midpoint of (-122.0883755, 37.3878978) and (-122.0862663, 37.3909118)
# map_list = [[<folium.folium.Map object at 0x10c4101d0>, <folium.folium.Map object at 0x10c435310>, <folium.folium.Map object at 0x10e79ae90>]]
# <iframe srcdoc="<table width=&quot;100%&quot;>
# <tr><td>&lt;iframe srcdoc=&quot;&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#    &lt;meta http-equiv=&amp;quot;content-type&amp;quot; content=&amp;quot;text/html; charset=UTF-8&amp;quot; /&gt;
#    &lt;link rel=&amp;quot;stylesheet&amp;quot; href=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&amp;quot; /&gt;
# ...

# %%
ipy.inline_maps([lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[0], "background/location", moving_df.iloc[2].start_ts, moving_df.iloc[2].end_ts)]) +
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[1], "background/location", moving_df.iloc[2].start_ts, moving_df.iloc[2].end_ts)]) + 
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[2], "background/location", moving_df.iloc[2].start_ts, moving_df.iloc[2].end_ts)])])
# Out:
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:sort_key = metadata.write_ts
# Found 0 points
# Found 576 points
# DEBUG:root:Getting midpoint of (-122.0862665, 37.3909145) and (-122.0862665, 37.3909142)
# DEBUG:root:sort_key = metadata.write_ts
# Found 462 points
# DEBUG:root:Getting midpoint of (-122.0829721, 37.3958724) and (-122.0862744, 37.3905949)
# map_list = [[<folium.folium.Map object at 0x10e6e6390>, <folium.folium.Map object at 0x10e6bc090>, <folium.folium.Map object at 0x10e65d190>]]
# <iframe srcdoc="<table width=&quot;100%&quot;>
# <tr><td>&lt;iframe srcdoc=&quot;&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#    &lt;meta http-equiv=&amp;quot;content-type&amp;quot; content=&amp;quot;text/html; charset=UTF-8&amp;quot; /&gt;
#    &lt;link rel=&amp;quot;stylesheet&amp;quot; href=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&amp;quot; /&gt;
# ...

# %%
ipy.inline_maps([lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[0], "background/location", moving_df.iloc[2].start_ts, moving_df.iloc[2].end_ts)]) +
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[1], "background/location", moving_df.iloc[2].start_ts, moving_df.iloc[2].end_ts)]) + 
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[2], "background/location", moving_df.iloc[2].start_ts, moving_df.iloc[2].end_ts)])])
# Out:
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:Getting midpoint of (-122.086361631246, 37.39065274812366) and (-122.0864090376478, 37.39063822897285)
# DEBUG:root:sort_key = metadata.write_ts
# Found 0 points
# Found 217 points
# Found 65 points
# DEBUG:root:Getting midpoint of (-122.0809025352439, 37.39954838799496) and (-122.086364797809, 37.39065016605583)
# map_list = [[<folium.folium.Map object at 0x10ee74c90>, <folium.folium.Map object at 0x10ee740d0>, <folium.folium.Map object at 0x10e7b1290>]]
# <iframe srcdoc="<table width=&quot;100%&quot;>
# <tr><td>&lt;iframe srcdoc=&quot;&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#    &lt;meta http-equiv=&amp;quot;content-type&amp;quot; content=&amp;quot;text/html; charset=UTF-8&amp;quot; /&gt;
#    &lt;link rel=&amp;quot;stylesheet&amp;quot; href=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&amp;quot; /&gt;
# ...

# %%
ipy.inline_maps([lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(android_ids[2], "background/location", moving_df.iloc[0].start_ts, moving_df.iloc[0].end_ts)]) + 
lo.get_maps_for_geojson_unsectioned([gfc.get_all_points_for_range(iphone_ids[2], "background/location", moving_df.iloc[0].start_ts, moving_df.iloc[0].end_ts)])])
# Out:
# DEBUG:root:sort_key = metadata.write_ts
# DEBUG:root:Getting midpoint of (-122.08749717, 37.38956949) and (-122.08901138, 37.38778794)
# DEBUG:root:sort_key = metadata.write_ts
# Found 104 points
# Found 62 points
# DEBUG:root:Getting midpoint of (-122.0864580107127, 37.39101596645768) and (-122.088715493002, 37.38810172456019)
# map_list = [[<folium.folium.Map object at 0x10e756c90>, <folium.folium.Map object at 0x10c43e210>]]
# <iframe srcdoc="<table width=&quot;100%&quot;>
# <tr><td>&lt;iframe srcdoc=&quot;&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#    &lt;meta http-equiv=&amp;quot;content-type&amp;quot; content=&amp;quot;text/html; charset=UTF-8&amp;quot; /&gt;
#    &lt;link rel=&amp;quot;stylesheet&amp;quot; href=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&amp;quot; /&gt;
#    &lt;script src=&amp;quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&amp;quot;&gt;&lt;/script&gt;
#
# ...
