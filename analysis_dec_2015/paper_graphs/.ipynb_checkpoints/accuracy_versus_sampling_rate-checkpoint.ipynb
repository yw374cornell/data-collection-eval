# %%
import sys

# %%
sys.path.insert(0, "/Users/shankari/e-mission/e-mission-server/")

# %%
sys.path
# Out:
# ['/Users/shankari/e-mission/e-mission-server/',
#  '',
#  '/Users/shankari/OSS/anaconda/lib/python2.7/site-packages/pygmaps-0.1.1-py2.7.egg',
#  '/Users/shankari/bin/python',
#  '/Users/shankari/e-mission/data-collection-eval/analysis_dec_2015/paper_graphs',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python27.zip',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/plat-darwin',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/plat-mac',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/plat-mac/lib-scriptpackages',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/lib-tk',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/lib-old',
#  '/Users/shankari/OSS/anaconda/python.app/Contents/lib/python2.7/lib-dynload',
#  '/Users/shankari/OSS/anaconda/lib/python2.7/site-packages',
# ...

# %%
import logging
logging.getLogger().setLevel(logging.DEBUG)

# %%
from uuid import UUID

# %%
iphone_ids = [UUID("079e0f1a-c440-3d7c-b0e7-de160f748e35"), UUID("c76a0487-7e5a-3b17-a449-47be666b36f6"), UUID("c528bcd2-a88b-3e82-be62-ef4f2396967a")]
android_ids = [UUID("e471711e-bd14-3dbe-80b6-9c7d92ecc296"), UUID("fd7b4c2e-2c8b-3bfa-94f0-d1e3ecbd5fb7"), UUID("86842c35-da28-32ed-a90e-2da6663c5c73")]

# %%
import emission.core.get_database as edb

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import datetime as pydt

# %%
phone_labels = ["ucb.sdb.ios.1", "ucb.sdb.ios.2", "ucb.sdb.ios.3", "ucb.sdb.android.1", "ucb.sdb.android.2", "ucb.sdb.android.3"]

# %%
def get_display_name(label):
    parts = label.split('.')
    return parts[2] + '.' + parts[3]

# %%
display_names = [get_display_name(label) for label in phone_labels]

# %%
drain_df_map = {}

# %%
drain_df_map["ios.1"] = pd.read_csv("../../results_dec_2015/ucb.sdb.ios.1/power_logs/noha5m_1449240600.log")
drain_df_map["ios.2"] = pd.read_csv("../../results_dec_2015/ucb.sdb.ios.2/power_logs/noma5m_1449240600.log")
drain_df_map["ios.3"] = pd.read_csv("../../results_dec_2015/ucb.sdb.ios.3/power_logs/noma50m_1449240600.log")

# %%
drain_df_map["android.1"] = pd.read_csv("../../results_dec_2015/ucb.sdb.android.1/power_logs/noha2s_1449240600.log")
drain_df_map["android.2"] = pd.read_csv("../../results_dec_2015/ucb.sdb.android.2/power_logs/noma2s_1449240600.log")
drain_df_map["android.3"] = pd.read_csv("../../results_dec_2015/ucb.sdb.android.3/power_logs/noma30s_1449240600.log")

# %%
for drain_df in drain_df_map.values():
    drain_df["fmt_time"] = drain_df.ts.map(lambda(t): pydt.datetime.fromtimestamp(t))

# %%
drain_df
# Out:
#               key            ts  value                fmt_time
# 0   battery_level  1.449241e+09    100 2015-12-04 06:50:00.000
# 1   battery_level  1.449242e+09    100 2015-12-04 07:18:33.010
# 2   battery_level  1.449244e+09    100 2015-12-04 07:49:38.490
# 3   battery_level  1.449248e+09     98 2015-12-04 08:48:16.890
# 4   battery_level  1.449249e+09     97 2015-12-04 09:14:10.980
# 5   battery_level  1.449251e+09     96 2015-12-04 09:47:34.600
# 6   battery_level  1.449253e+09     94 2015-12-04 10:21:14.840
# 7   battery_level  1.449256e+09     92 2015-12-04 10:58:20.710
# 8   battery_level  1.449258e+09     90 2015-12-04 11:33:30.870
# 9   battery_level  1.449259e+09     89 2015-12-04 11:54:25.500
# 10  battery_level  1.449260e+09     88 2015-12-04 12:11:00.560
# 11  battery_level  1.449262e+09     86 2015-12-04 12:45:41.870
# 12  battery_level  1.449264e+09     84 2015-12-04 13:22:03.260
# 13  battery_level  1.449267e+09     81 2015-12-04 14:15:37.640
# ...

# %%
sel_df = drain_df[drain_df.index.isin([0,4,17,22,23])][["ts", "fmt_time", "value"]]; sel_df
# Out:
#               ts                fmt_time  value
# 0   1.449241e+09 2015-12-04 06:50:00.000    100
# 4   1.449249e+09 2015-12-04 09:14:10.980     97
# 17  1.449277e+09 2015-12-04 16:48:34.190     72
# 22  1.449287e+09 2015-12-04 19:39:01.290     63
# 23  1.449328e+09 2015-12-05 07:03:22.210     41

# %%
sel_df.iloc[1:]
# Out:
#               ts                fmt_time  value
# 4   1.449249e+09 2015-12-04 09:14:10.980     97
# 17  1.449277e+09 2015-12-04 16:48:34.190     72
# 22  1.449287e+09 2015-12-04 19:39:01.290     63
# 23  1.449328e+09 2015-12-05 07:03:22.210     41

# %%
sel_df.iloc[1:].reset_index()
# Out:
#    index            ts                fmt_time  value
# 0      4  1.449249e+09 2015-12-04 09:14:10.980     97
# 1     17  1.449277e+09 2015-12-04 16:48:34.190     72
# 2     22  1.449287e+09 2015-12-04 19:39:01.290     63
# 3     23  1.449328e+09 2015-12-05 07:03:22.210     41

# %%
pd.concat([sel_df.reset_index(), sel_df.iloc[1:].reset_index()], axis=1)
# Out:
#    index            ts                fmt_time  value  index            ts  \
# 0      0  1.449241e+09 2015-12-04 06:50:00.000    100      4  1.449249e+09
# 1      4  1.449249e+09 2015-12-04 09:14:10.980     97     17  1.449277e+09
# 2     17  1.449277e+09 2015-12-04 16:48:34.190     72     22  1.449287e+09
# 3     22  1.449287e+09 2015-12-04 19:39:01.290     63     23  1.449328e+09
# 4     23  1.449328e+09 2015-12-05 07:03:22.210     41    NaN           NaN
#
#                  fmt_time  value
# 0 2015-12-04 09:14:10.980     97
# 1 2015-12-04 16:48:34.190     72
# 2 2015-12-04 19:39:01.290     63
# 3 2015-12-05 07:03:22.210     41
# 4                     NaT    NaN

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,3))
drain_df_map["ios.1"].plot(x="ts", y="value", label="ha5m", ax=axes[0])
drain_df_map["ios.2"].plot(x="ts", y="value", label="ma5m", ax=axes[0])
drain_df_map["ios.3"].plot(x="ts", y="value", label="ma50m", ax=axes[0])
drain_df_map["android.1"].plot(x="ts", y="value", label="ha2s", ax=axes[1])
drain_df_map["android.2"].plot(x="ts", y="value", label="ma2s", ax=axes[1])
drain_df_map["android.3"].plot(x="ts", y="value", label="ma30s", ax=axes[1])

for j in range(2):
    axes[j].axvspan(xmin=drain_df.ts[0], xmax=drain_df.ts[4], color="red", alpha=0.3, label="moving")
    axes[j].axvspan(xmin=drain_df.ts[4], xmax=drain_df.ts[17], color="blue", alpha=0.3, label="active")
    axes[j].axvspan(xmin=drain_df.ts[17], xmax=drain_df.ts[22], color="red", alpha=0.3, label="moving")
    axes[j].axvspan(xmin=drain_df.ts[22], xmax=drain_df.ts[23], color="green", alpha=0.3, label="passive")

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,3))
axes[0].set_title("android")
axes[1].set_title("iOS")
drain_df_map["android.1"].plot(x="fmt_time", y="value", label="ha2s", ax=axes[0])
drain_df_map["android.2"].plot(x="fmt_time", y="value", label="ma2s", ax=axes[0])
drain_df_map["android.3"].plot(x="fmt_time", y="value", label="ma30s", ax=axes[0])
drain_df_map["ios.1"].plot(x="fmt_time", y="value", label="ha5m", ax=axes[1])
drain_df_map["ios.2"].plot(x="fmt_time", y="value", label="ma5m", ax=axes[1])
drain_df_map["ios.3"].plot(x="fmt_time", y="value", label="ma50m", ax=axes[1])


for j in range(2):
    axes[j].axvspan(xmin=drain_df.fmt_time[0], xmax=drain_df.fmt_time[4], color="red", alpha=0.2, label="moving")
    axes[j].annotate("moving", xy=(drain_df.fmt_time[0], 50), xycoords='data', fontsize=12, color="red")
    axes[j].axvspan(xmin=drain_df.fmt_time[4], xmax=drain_df.fmt_time[17], color="blue", alpha=0.2, label="active")
    axes[j].annotate("active", xy=(drain_df.fmt_time[4] + pydt.timedelta(hours=1), 50), xycoords='data', fontsize=12, color="blue")
    axes[j].axvspan(xmin=drain_df.fmt_time[17], xmax=drain_df.fmt_time[22], color="red", alpha=0.2, label="moving")
    axes[j].annotate("moving", xy=(drain_df.fmt_time[17], 50), xycoords='data', fontsize=12, color="red")
    axes[j].axvspan(xmin=drain_df.fmt_time[22], xmax=drain_df.fmt_time[23], color="green", alpha=0.2, label="passive")
    axes[j].annotate("passive", xy=(drain_df.fmt_time[22] + pydt.timedelta(hours=1), 50), xycoords='data', fontsize=12, color="green")
